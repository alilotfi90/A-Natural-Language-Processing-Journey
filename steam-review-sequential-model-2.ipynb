# %% [markdown]
# <a href="https://colab.research.google.com/github/alilotfi90/A-Natural-Language-Processing-Journey/blob/main/steam-review-sequential-model-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.pipeline import Pipeline

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding



nltk.download('punkt')
nltk.download('stopwords')

drive.mount('/content/drive')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/steam_data_set.zip" -d "/content/"
# Out:
# Archive:  /content/drive/MyDrive/steam_data_set.zip
#   inflating: /content/test_gr/test.csv
#   inflating: /content/train_gr/game_overview.csv
#   inflating: /content/train_gr/train.csv

# %%
data_path = "/content/train_gr/train.csv"
df = pd.read_csv(data_path)

# Explore first few rows of the DataFrame
print(df.head())
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...                1
# 1  Best game, more better than Sam Pepper's YouTu...                1
# 2  A littly iffy on the controls, but once you kn...                1
# 3  Great game, fun and colorful and all that.A si...                1
# 4  Not many games have the cute tag right next to...                1

# %%
def preprocess_text(text):
    tokens = word_tokenize(text.lower())  # Tokenization and case normalization
    tokens = [word for word in tokens if word.isalpha()]  # Keep words only
    tokens = [word for word in tokens if word not in stopwords.words('english')]  # Remove stopwords
    return ' '.join(tokens)

df['cleaned_review'] = df['user_review'].apply(preprocess_text)

df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review  user_suggestion  \
# 0  I'm scared and hearing creepy voices.  So I'll...                1
# 1  Best game, more better than Sam Pepper's YouTu...                1
# 2  A littly iffy on the controls, but once you kn...                1
# 3  Great game, fun and colorful and all that.A si...                1
# 4  Not many games have the cute tag right next to...                1
#
#                                       cleaned_review
# 0  scared hearing creepy voices pause moment writ...
# 1  best game better sam pepper youtube account ne...
# 2  littly iffy controls know play easy master mad...
# 3  great game fun colorful side note though getti...
# 4  many games cute tag right next horror tag firs...

# %%
# Tokenization and Padding
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['cleaned_review'])
sequences = tokenizer.texts_to_sequences(df['cleaned_review'])
padded_sequences = pad_sequences(sequences, maxlen=100, padding='post', truncating='post')
padded_sequences_1 = pad_sequences(sequences, maxlen=200, padding='post', truncating='post')

# Build LSTM Model 1
model_1 = Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=32, input_length=200),
    LSTM(32),
    Dense(1, activation='sigmoid')
])


# Build LSTM Model 2
model_2 = Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=100),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

# %%
model_1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model_2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, df['user_suggestion'].values, test_size=0.3, random_state=42)
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(padded_sequences_1, df['user_suggestion'].values, test_size=0.3, random_state=42)

# List of epochs
epoch_list = [5, 10, 20,40]

# Model Training with different epochs
for epoch in epoch_list:
    print(f'\nTraining model for {epoch} epochs...\n')

    model_1.fit(X_train_1, y_train_1, validation_data=(X_test_1, y_test_1), epochs=epoch, batch_size=32)

    test_loss, test_acc = model_1.evaluate(X_test_1, y_test_1, verbose=2)
    print(f'\nTest accuracy after {epoch} epochs for model_1 which had input_lenght = 200:', test_acc, '\n')


    model_2.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epoch, batch_size=32)

    test_loss, test_acc = model_2.evaluate(X_test, y_test, verbose=2)
    print(f'\nTest accuracy after {epoch} epochs for model_2 which had output_dim = 64:', test_acc, '\n')
# Out:
# Training model for 5 epochs...
#
# Epoch 1/5
# 383/383 [==============================] - 79s 182ms/step - loss: 0.6847 - accuracy: 0.5664 - val_loss: 0.6800 - val_accuracy: 0.5771
# Epoch 2/5
# 383/383 [==============================] - 35s 93ms/step - loss: 0.6798 - accuracy: 0.5791 - val_loss: 0.6770 - val_accuracy: 0.5875
# Epoch 3/5
# 383/383 [==============================] - 24s 61ms/step - loss: 0.6582 - accuracy: 0.5942 - val_loss: 0.6818 - val_accuracy: 0.5860
# Epoch 4/5
# 383/383 [==============================] - 14s 36ms/step - loss: 0.6467 - accuracy: 0.5954 - val_loss: 0.6960 - val_accuracy: 0.5843
# Epoch 5/5
# 383/383 [==============================] - 10s 25ms/step - loss: 0.6441 - accuracy: 0.5980 - val_loss: 0.6963 - val_accuracy: 0.5854
# 165/165 - 1s - loss: 0.6963 - accuracy: 0.5854 - 887ms/epoch - 5ms/step
#
# Test accuracy after 5 epochs for model_1 which had input_lenght = 200: 0.5854448676109314
#
# Epoch 1/5
# 383/383 [==============================] - 60s 150ms/step - loss: 0.6809 - accuracy: 0.5767 - val_loss: 0.6528 - val_accuracy: 0.6281
# Epoch 2/5
# 383/383 [==============================] - 24s 62ms/step - loss: 0.6641 - accuracy: 0.6051 - val_loss: 0.6560 - val_accuracy: 0.5967
# Epoch 3/5
# 383/383 [==============================] - 12s 31ms/step - loss: 0.5803 - accuracy: 0.7161 - val_loss: 0.5408 - val_accuracy: 0.7636
# Epoch 4/5
# 383/383 [==============================] - 10s 27ms/step - loss: 0.4758 - accuracy: 0.8136 - val_loss: 0.5371 - val_accuracy: 0.7691
# Epoch 5/5
# 383/383 [==============================] - 7s 18ms/step - loss: 0.4685 - accuracy: 0.8122 - val_loss: 0.5539 - val_accuracy: 0.7630
# 165/165 - 1s - loss: 0.5539 - accuracy: 0.7630 - 532ms/epoch - 3ms/step
#
# Test accuracy after 5 epochs for model_2 which had output_dim = 64: 0.7630024552345276
#
#
# Training model for 10 epochs...
#
# Epoch 1/10
# 383/383 [==============================] - 12s 33ms/step - loss: 0.6416 - accuracy: 0.5990 - val_loss: 0.7455 - val_accuracy: 0.5782
# Epoch 2/10
# 383/383 [==============================] - 10s 27ms/step - loss: 0.6472 - accuracy: 0.5965 - val_loss: 0.6959 - val_accuracy: 0.5870
# Epoch 3/10
# 383/383 [==============================] - 9s 23ms/step - loss: 0.6425 - accuracy: 0.5987 - val_loss: 0.6989 - val_accuracy: 0.5864
# Epoch 20/20
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0333 - accuracy: 0.9900 - val_loss: 2.2335 - val_accuracy: 0.5140
# 165/165 - 1s - loss: 2.2335 - accuracy: 0.5140 - 757ms/epoch - 5ms/step
#
# Test accuracy after 20 epochs for model_1 which had input_lenght = 200: 0.5140026807785034
#
# Epoch 1/20
# 383/383 [==============================] - 4s 11ms/step - loss: 0.2777 - accuracy: 0.9041 - val_loss: 0.5323 - val_accuracy: 0.7950
# Epoch 2/20
# 383/383 [==============================] - 5s 14ms/step - loss: 0.2430 - accuracy: 0.9160 - val_loss: 0.5426 - val_accuracy: 0.7910
# Epoch 3/20
# 383/383 [==============================] - 5s 13ms/step - loss: 0.2231 - accuracy: 0.9294 - val_loss: 0.5226 - val_accuracy: 0.7893
# Epoch 4/20
# 383/383 [==============================] - 4s 10ms/step - loss: 0.1955 - accuracy: 0.9402 - val_loss: 0.5807 - val_accuracy: 0.7990
# Epoch 5/20
# 383/383 [==============================] - 6s 15ms/step - loss: 0.1678 - accuracy: 0.9520 - val_loss: 0.6010 - val_accuracy: 0.7979
# Epoch 6/20
# 383/383 [==============================] - 4s 11ms/step - loss: 0.1539 - accuracy: 0.9581 - val_loss: 0.6630 - val_accuracy: 0.8000
# Epoch 7/20
# 383/383 [==============================] - 5s 13ms/step - loss: 0.1436 - accuracy: 0.9600 - val_loss: 0.6394 - val_accuracy: 0.8003
# Epoch 8/20
# 383/383 [==============================] - 6s 16ms/step - loss: 0.1491 - accuracy: 0.9584 - val_loss: 0.6247 - val_accuracy: 0.8057
# Epoch 9/20
# 383/383 [==============================] - 4s 12ms/step - loss: 0.1651 - accuracy: 0.9495 - val_loss: 0.5720 - val_accuracy: 0.7681
# Epoch 10/20
# 383/383 [==============================] - 5s 14ms/step - loss: 0.1495 - accuracy: 0.9560 - val_loss: 0.5812 - val_accuracy: 0.7990
# Epoch 11/20
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0903 - accuracy: 0.9744 - val_loss: 0.6644 - val_accuracy: 0.8061
# Epoch 12/20
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0572 - accuracy: 0.9844 - val_loss: 0.7447 - val_accuracy: 0.8110
# Epoch 13/20
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0382 - accuracy: 0.9907 - val_loss: 0.8375 - val_accuracy: 0.8032
# Epoch 14/20
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0302 - accuracy: 0.9926 - val_loss: 0.8643 - val_accuracy: 0.8022
# Epoch 15/20
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0227 - accuracy: 0.9951 - val_loss: 0.8856 - val_accuracy: 0.8022
# Epoch 16/20
# 383/383 [==============================] - 4s 9ms/step - loss: 0.0170 - accuracy: 0.9963 - val_loss: 0.9291 - val_accuracy: 0.8062
# Epoch 17/20
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0138 - accuracy: 0.9970 - val_loss: 0.9125 - val_accuracy: 0.8026
# Epoch 18/20
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0137 - accuracy: 0.9975 - val_loss: 0.9058 - val_accuracy: 0.7984
# Epoch 19/20
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0100 - accuracy: 0.9980 - val_loss: 0.9884 - val_accuracy: 0.7979
# Epoch 20/20
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 1.0600 - val_accuracy: 0.7965
# 165/165 - 1s - loss: 1.0600 - accuracy: 0.7965 - 658ms/epoch - 4ms/step
#
# Test accuracy after 20 epochs for model_2 which had output_dim = 64: 0.7965326905250549
#
#
# Training model for 40 epochs...
#
# Epoch 1/40
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0522 - accuracy: 0.9840 - val_loss: 2.0988 - val_accuracy: 0.5214
# Epoch 2/40
# 383/383 [==============================] - 7s 19ms/step - loss: 0.0410 - accuracy: 0.9880 - val_loss: 2.0823 - val_accuracy: 0.5098
# Epoch 3/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0297 - accuracy: 0.9919 - val_loss: 2.2433 - val_accuracy: 0.5186
# Epoch 4/40
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0297 - accuracy: 0.9918 - val_loss: 2.2566 - val_accuracy: 0.5220
# Epoch 5/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0207 - accuracy: 0.9955 - val_loss: 2.3721 - val_accuracy: 0.5182
# Epoch 6/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0198 - accuracy: 0.9940 - val_loss: 2.5072 - val_accuracy: 0.5150
# Epoch 7/40
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0188 - accuracy: 0.9945 - val_loss: 2.5743 - val_accuracy: 0.5167
# Epoch 8/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0411 - accuracy: 0.9858 - val_loss: 2.3318 - val_accuracy: 0.5068
# Epoch 9/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0613 - accuracy: 0.9816 - val_loss: 2.1428 - val_accuracy: 0.5172
# Epoch 10/40
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0362 - accuracy: 0.9894 - val_loss: 2.2326 - val_accuracy: 0.5113
# Epoch 11/40
# 383/383 [==============================] - 5s 12ms/step - loss: 0.1315 - accuracy: 0.9588 - val_loss: 1.8766 - val_accuracy: 0.5142
# Epoch 12/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0314 - accuracy: 0.9909 - val_loss: 2.1490 - val_accuracy: 0.5115
# Epoch 13/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 2.3710 - val_accuracy: 0.5104
# Epoch 14/40
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0071 - accuracy: 0.9988 - val_loss: 2.5130 - val_accuracy: 0.5111
# Epoch 15/40
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0058 - accuracy: 0.9993 - val_loss: 2.6389 - val_accuracy: 0.5113
# Epoch 16/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 2.6624 - val_accuracy: 0.5136
# Epoch 17/40
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 2.7473 - val_accuracy: 0.5089
# Epoch 18/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0108 - accuracy: 0.9961 - val_loss: 2.7296 - val_accuracy: 0.5102
# Epoch 19/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0285 - accuracy: 0.9909 - val_loss: 2.6321 - val_accuracy: 0.5073
# Epoch 20/40
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0303 - accuracy: 0.9904 - val_loss: 2.5020 - val_accuracy: 0.5092
# Epoch 21/40
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0191 - accuracy: 0.9941 - val_loss: 2.5872 - val_accuracy: 0.5081
# Epoch 22/40
# 383/383 [==============================] - 7s 20ms/step - loss: 0.0136 - accuracy: 0.9966 - val_loss: 2.5815 - val_accuracy: 0.5138
# Epoch 23/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 2.7547 - val_accuracy: 0.5127
# Epoch 24/40
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 2.7234 - val_accuracy: 0.5151
# Epoch 25/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0832 - accuracy: 0.9788 - val_loss: 2.0478 - val_accuracy: 0.5119
# Epoch 26/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0578 - accuracy: 0.9819 - val_loss: 2.1655 - val_accuracy: 0.5150
# Epoch 27/40
# 383/383 [==============================] - 6s 14ms/step - loss: 0.0155 - accuracy: 0.9965 - val_loss: 2.2996 - val_accuracy: 0.5146
# Epoch 28/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 2.4905 - val_accuracy: 0.5131
# Epoch 29/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 2.6193 - val_accuracy: 0.5132
# Epoch 30/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 2.7216 - val_accuracy: 0.5129
# Epoch 31/40
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 2.8192 - val_accuracy: 0.5134
# Epoch 32/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 2.8066 - val_accuracy: 0.5094
# Epoch 33/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0363 - accuracy: 0.9900 - val_loss: 2.4967 - val_accuracy: 0.5119
# Epoch 34/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0282 - accuracy: 0.9920 - val_loss: 2.4024 - val_accuracy: 0.5127
# Epoch 35/40
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0251 - accuracy: 0.9933 - val_loss: 2.4605 - val_accuracy: 0.5119
# Epoch 36/40
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0138 - accuracy: 0.9965 - val_loss: 2.5444 - val_accuracy: 0.5121
# Epoch 37/40
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 2.7360 - val_accuracy: 0.5100
# Epoch 38/40
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0076 - accuracy: 0.9982 - val_loss: 2.7095 - val_accuracy: 0.5163
# Epoch 39/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 2.8489 - val_accuracy: 0.5098
# Epoch 40/40
# 383/383 [==============================] - 6s 14ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 2.8457 - val_accuracy: 0.5193
# 165/165 - 1s - loss: 2.8457 - accuracy: 0.5193 - 941ms/epoch - 6ms/step
#
# Test accuracy after 40 epochs for model_1 which had input_lenght = 200: 0.519336998462677
#
# Epoch 1/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0112 - accuracy: 0.9977 - val_loss: 0.8734 - val_accuracy: 0.7960
# Epoch 2/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0097 - accuracy: 0.9972 - val_loss: 1.0686 - val_accuracy: 0.7960
# Epoch 3/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 1.0906 - val_accuracy: 0.7982
# Epoch 4/40
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 1.0519 - val_accuracy: 0.7990
# Epoch 5/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 1.1444 - val_accuracy: 0.7981
# Epoch 6/40
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 1.2255 - val_accuracy: 0.7982
# Epoch 7/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 1.3046 - val_accuracy: 0.8019
# Epoch 8/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 1.2253 - val_accuracy: 0.7979
# Epoch 9/40
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 1.2568 - val_accuracy: 0.7946
# Epoch 10/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 1.0497 - val_accuracy: 0.7965
# Epoch 11/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 1.1466 - val_accuracy: 0.7868
# Epoch 12/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 1.1316 - val_accuracy: 0.7950
# Epoch 13/40
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 1.2921 - val_accuracy: 0.7948
# Epoch 14/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.3654 - val_accuracy: 0.7971
# Epoch 15/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 1.5064 - val_accuracy: 0.7939
# Epoch 16/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.3446 - val_accuracy: 0.7967
# Epoch 17/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 1.4885 - val_accuracy: 0.7956
# Epoch 18/40
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.3928 - val_accuracy: 0.7992
# Epoch 19/40
# 383/383 [==============================] - 5s 12ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 1.5428 - val_accuracy: 0.7981
# Epoch 20/40
# 383/383 [==============================] - 5s 13ms/step - loss: 9.9814e-04 - accuracy: 0.9996 - val_loss: 1.6624 - val_accuracy: 0.7996
# Epoch 21/40
# 383/383 [==============================] - 4s 9ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 1.5394 - val_accuracy: 0.7956
# Epoch 22/40
# 383/383 [==============================] - 4s 10ms/step - loss: 8.3732e-04 - accuracy: 0.9997 - val_loss: 1.6864 - val_accuracy: 0.7998
# Epoch 23/40
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 1.1102 - val_accuracy: 0.7992
# Epoch 24/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0133 - accuracy: 0.9967 - val_loss: 1.0151 - val_accuracy: 0.7973
# Epoch 25/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 1.3299 - val_accuracy: 0.7981
# Epoch 26/40
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 1.3051 - val_accuracy: 0.7994
# Epoch 27/40
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.4217 - val_accuracy: 0.7979
# Epoch 28/40
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 1.4403 - val_accuracy: 0.7979
# Epoch 29/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.4864 - val_accuracy: 0.7967
# Epoch 30/40
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 1.4880 - val_accuracy: 0.7979
# Epoch 31/40
# 383/383 [==============================] - 3s 9ms/step - loss: 8.5383e-04 - accuracy: 0.9995 - val_loss: 1.6739 - val_accuracy: 0.7979
# Epoch 32/40
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 1.5749 - val_accuracy: 0.7962
# Epoch 33/40
# 383/383 [==============================] - 4s 12ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 1.7177 - val_accuracy: 0.7933
# Epoch 34/40
# 383/383 [==============================] - 4s 10ms/step - loss: 9.9356e-04 - accuracy: 0.9996 - val_loss: 1.7314 - val_accuracy: 0.7931
# Epoch 35/40
# 383/383 [==============================] - 3s 9ms/step - loss: 9.9717e-04 - accuracy: 0.9995 - val_loss: 1.6067 - val_accuracy: 0.7927
# Epoch 36/40
# 383/383 [==============================] - 4s 9ms/step - loss: 9.3210e-04 - accuracy: 0.9997 - val_loss: 1.6860 - val_accuracy: 0.7954
# Epoch 37/40
# 383/383 [==============================] - 4s 11ms/step - loss: 9.8277e-04 - accuracy: 0.9995 - val_loss: 1.6433 - val_accuracy: 0.7946
# Epoch 38/40
# 383/383 [==============================] - 4s 10ms/step - loss: 9.4931e-04 - accuracy: 0.9994 - val_loss: 1.6915 - val_accuracy: 0.7958
# Epoch 39/40
# 383/383 [==============================] - 4s 10ms/step - loss: 9.0107e-04 - accuracy: 0.9995 - val_loss: 1.7880 - val_accuracy: 0.7967
# Epoch 40/40
# 383/383 [==============================] - 4s 11ms/step - loss: 9.7503e-04 - accuracy: 0.9997 - val_loss: 1.8325 - val_accuracy: 0.7942
# 165/165 - 1s - loss: 1.8325 - accuracy: 0.7942 - 741ms/epoch - 4ms/step
#
# Test accuracy after 40 epochs for model_2 which had output_dim = 64: 0.79424649477005
